# %% [markdown]
# <a href="https://colab.research.google.com/github/dniggl/Insights/blob/main/Twitter_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Tweepy
pip install tweepy

# %%
# Importing the libraries.
import os
import tweepy as tw
import pandas as pd
import numpy as np

# Connecting to your Twitter Developer API's.
api_key= 'API Key Here' 
api_secret= 'API Secret Key Here'
access_token= 'Access Token Here'
access_token_secret= 'Access Token Secret Here'

# Authenticate the APIs
auth = tw.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# Define the search words and the date_since date as variables.
search_words = "LA rams"
date_since = "2022-01-01"

# Collect the tweets.
tweets = tw.Cursor(api.search,
              q = search_words,
              lang = "en",
              since = date_since).items(5)

# Define a function to get the related tweets.
def get_related_tweets(key_word):
    twitter_users = []
    tweet_time = []
    tweet_string = [] 
    for tweet in tw.Cursor(api.search,q=key_word, count=1000).items(1000):
            if (not tweet.retweeted) and ('RT @' not in tweet.text):
                if tweet.lang == "en":
                    twitter_users.append(tweet.user.name)
                    tweet_time.append(tweet.created_at)
                    tweet_string.append(tweet.text)
                    
    df = pd.DataFrame({'name':twitter_users, 'time': tweet_time, 'tweet': tweet_string})
    df.to_csv(f"{key_word}.csv")
    return df

# Get tweets related to LA Rams and create a new dataframe.
df = get_related_tweets("LA Rams")
df.head(7)
# Out:
#                              name                time  \
# 0                   Ghost of Joad 2022-05-28 17:38:59
# 1      YO FAVORITE DODGERS FAN!!! 2022-05-28 17:36:14
# 2                    Reoat9000 ☪️ 2022-05-28 17:26:48
# 3  World Champion Rams RamilyWood 2022-05-28 16:43:35
# 4                     Robbin Mote 2022-05-28 16:41:09
# 5                              ZK 2022-05-28 16:40:05
# 6      SUPER BOWL CHAMPS - E*0D 🫠 2022-05-28 16:38:03
#
#                                                tweet
# 0  @Uchiha_Hirsch @Eastbayluv_510 @DonaldIan_ @Bi...
# 1  @RamilyWood Idk the Rams have a bunch of playe...
# 2  @Embiid_prodzz STL, it makes no sense, you mov...
# 3  @sf_derek What they did with 2 folks is lame c...
# 4  @Embiid_prodzz 😄 Seattle looks so lonely up th...
# 5  @spotrac Maybe they need to by a SB just the L...
# 6  Good morning everyone. Just wanted the remind ...
